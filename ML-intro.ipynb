# %% [markdown]
# Machine Learning Basics

# %%
print("hello from jupyter")
# Out:
# hello from jupyter

# %% [markdown]
# # Types of ML Model
# Regression
# Classification
# Clustering

# %% [markdown]
# # 1.Regression
# # To predict continuous values from the given data
#
# Steps:
# 1.import the required libraries
# 2.gather the required data
#
#
# 1.define features[x] and target[y]
# 2.splitting data into training and testing dataset
# 3.use training to train the model
# 4.use testing data to test the model
# 5.visualise the final model

# %% [markdown]
# # Step 1:Importing the required libraries

# %%
pip install numpy pandas scikit-learn matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# # Experimenting with random data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import numpy as np

# %%
randomdata=np.random.RandomState(1)
x=10 * randomdata.rand(50)
y=2 * x - 5 + np.random.rand(50)
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x[:, np.newaxis], y)

xfit=np.linspace(0, 10, 100)
yfit=model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit, color='green')
